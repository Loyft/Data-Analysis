# %%
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
df1 = pd.read_csv("/Users/basti/Documents/Coding Projects/Data Analyst/Data Prep/05 - Pandas data source/df1", index_col=0)
df2 = pd.read_csv("/Users/basti/Documents/Coding Projects/Data Analyst/Data Prep/05 - Pandas data source/df2", index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#                  b         c         d
# a
# 0.039762  0.218517  0.103423  0.957904
# 0.937288  0.041567  0.899125  0.977680
# 0.780504  0.008948  0.557808  0.797510
# 0.672717  0.247870  0.264071  0.444358
# 0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
df1['A'].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.area()
# Out:
# <AxesSubplot:xlabel='a'>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='a'>

# %%
df1.plot.line(x=df1.index, y='B', figsize=(12, 3), lw=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-2d73935fffed> in <module>
# ----> 1 df1.plot.line(x=df1.index, y='B', figsize=(12, 3), lw=1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in line(self, x, y, **kwargs)
#    1015         as coordinates.
#    1016         """
# -> 1017         return self(kind="line", x=x, y=y, **kwargs)
#    1018
#    1019     @Appender(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     912                 if is_integer(x) and not data.columns.holds_integer():
#     913                     x = data_cols[x]
# --> 914                 elif not isinstance(data[x], ABCSeries):
#     915                     raise ValueError("x must be a label or position")
#     916                 data = data.set_index(x)
#
# ...

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*50)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### make dataframe with random numbers

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

# %%
df.plot.hexbin(x='a', y='b', gridsize=20)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
